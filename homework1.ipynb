# %% [markdown]
# bài 1

# %%
n = int(input("Nhap n: "))
print("So gap doi la:", n * 2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 n = int(input("Nhap n: "))
#       2 print("So gap doi la:", n * 2)
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# bài 2

# %%
a = float(input("Nhap chieu rong a: "))
b = float(input("Nhap chieu dai b: "))

pi = 3.14
r = min(a, b) / 2

dien_tich_hcn = a * b
dien_tich_tron = pi * r * r

ket_qua = dien_tich_hcn - dien_tich_tron

print("Dien tich con lai:", round(ket_qua, 2))

# %% [markdown]
# bài 3

# %%
c = input("Nhap ky tu: ")

if c.isupper():
    print(c.lower())
else:
    print(c.upper())

# %% [markdown]
# bài 4

# %%
c = input("Nhap ky tu: ")

if c.isalpha():
    print(c, "la ki tu alphabet")
else:
    print(c, "khong phai la ki tu alphabet")

# %% [markdown]
# bài 5

# %%
c = input("Nhap chu hoa: ")

c = c.lower()

if c == 'a':
    print("Khong co chu dung truoc")
else:
    print(chr(ord(c) - 1))
# Out:
# e

# %% [markdown]
# bài 6

# %%
import math

a = float(input("Nhap a: "))
b = float(input("Nhap b: "))
c = float(input("Nhap c: "))

if a + b > c and a + c > b and b + c > a:
    p = (a + b + c) / 2
    s = math.sqrt(p * (p - a) * (p - b) * (p - c))
    print("Dien tich:", round(s, 1))
else:
    print("Khong phai 3 canh cua tam giac")

# %% [markdown]
# bài 7

# %%
s = input("Nhap chuoi >=20 ky tu: ")

print("Ky tu thu 5:", s[4])
print("Ky tu thu 9:", s[8])

# %% [markdown]
# bài 8

# %%
ten = input("Ten chu ho: ")
truoc = int(input("Chi so thang truoc: "))
nay = int(input("Chi so thang nay: "))

kwh = nay - truoc
tien = 0

if kwh <= 50:
    tien = kwh * 1984
elif kwh <= 100:
    tien = 50 * 1984 + (kwh - 50) * 2050
elif kwh <= 200:
    tien = 50 * 1984 + 50 * 2050 + (kwh - 100) * 2380
elif kwh <= 300:
    tien = 50 * 1984 + 50 * 2050 + 100 * 2380 + (kwh - 200) * 2998
elif kwh <= 400:
    tien = 50 * 1984 + 50 * 2050 + 100 * 2380 + 100 * 2998 + (kwh - 300) * 3350
else:
    tien = 50 * 1984 + 50 * 2050 + 100 * 2380 + 100 * 2998 + 100 * 3350 + (kwh - 400) * 3460

tien = tien * 1.08

print("Ho va ten:", ten)
print("Tien phai tra la:", int(tien))

# %% [markdown]
# bài tập khác

# %% [markdown]
# bài 1

# %%
n=int(input("nhập một số nguyên: "))
if n % 2 == 0:
       print("số chẵn")
else:
       print("số lẻ")

# %% [markdown]
# bài 2

# %%
n =  int(input("nhập một số nguyên: "))
if n % 10 == 5:
    print("True")
else:
    print("False")
# Out:
# False

# %% [markdown]
# bài 3

# %%
n =  int(input("nhập một số nguyên: "))
if n % 3 == 0 and n % 5 == 0:
    print("True")
else:
    print("False")

# %% [markdown]
# bài 4

# %%
n =  int(input("nhập một số nguyên: "))
if n<=2007:
    print("True")
else:
    print("False")
# Out:
# True

# %% [markdown]
# bài 5

# %%
a = float(input("nhập số: "))
b = float(input("nhập số: "))
if a > b:
    print("a lớn hơn b")
elif a == b:
    print("a bằng b")
else:
    print("a nhỏ hơn b")
# Out:
# a nhỏ hơn b

# %% [markdown]
# bài 6

# %%
ky_tu = input("Nhập một ký tự: ")

if ky_tu.isalpha():
    print("Đây là chữ cái")
elif ky_tu.isdigit():
    print("Đây là chữ số")
else:
    print("Không phải chữ cái cũng không phải chữ số")
# Out:
# Đây là chữ cái

# %% [markdown]
# bài 7

# %%
n =  int(input("nhập điểm: "))
if 10>= n >=8:
    print("giỏi")
elif 8>= n >=6.5:
    print("khá")
elif 6.5 >n >=5:
    print("trung bình")
elif 5 > n >=0:
    print("yếu")
# Out:
# yếu

# %% [markdown]
# bài 8
